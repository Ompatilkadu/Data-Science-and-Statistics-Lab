# %%
#Exp no: 7
#Aim : Perform a simple linear regression

# %%
#Name:Om M. Kadu
#Rollno:27
#Sec:B
#Subject:Emerging Tech Lab-1

# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\USER\\OneDrive\\Desktop'

# %%
os.chdir("C:\\Users\\USER\\OneDrive\\Desktop")

# %%
data=pd.read_csv("Salary_Data.csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.size
# Out:
# 60

# %%
data.shape
# Out:
# (30, 2)

# %%
data.ndim
# Out:
# 2

# %%
data.mean()
# Out:
# YearsExperience        5.313333
# Salary             76003.000000
# dtype: float64

# %%
data.median()
# Out:
# YearsExperience        4.7
# Salary             65237.0
# dtype: float64

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %% [markdown]
# # dependent and independent variable

# %%
x=data.drop('Salary',axis=1)

# %%
x.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
y=data.Salary

# %%
y.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,15,30]
plt.Bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18328/3900219594.py in <module>
#       2 x=[1,2,3,4,5]
#       3 y=[10,20,15,30]
# ----> 4 plt.Bar(x,y)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Bar'
