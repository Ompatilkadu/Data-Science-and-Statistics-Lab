# %% [markdown]
# <h1 style="color: black; text-align: center; font-family: Arial, sans-serif; font-size: 32px;">
#   BASICS OF DATA FRAME
# </h1>

# %%
#EXP NO 3
#AIM:BASICS OF DATA FRAME

# %%
#Name:Om M. Kadu
#Rollno:27
#Sec:B
#Subject:Dss

# %%
#import pandas library
import pandas as pd

# %%
#Creating Data Frame
df=pd.DataFrame([[10,12,15,17],[15,14,11,16],[14,11,19,17]],
columns=["CD","DBMS","CAO","DSS"])

# %%
df
# Out:
#    CD  DBMS  CAO  DSS
# 0  10    12   15   17
# 1  15    14   11   16
# 2  14    11   19   17

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %%
df2=pd.DataFrame([[5,6,7,8]],
columns=["CD","CAO","DSS","DBMS"])

# %%
df3=df.append(df2,ignore_index=True)

# %%
df3
# Out:
#    CD  DBMS  CAO  DSS
# 0  10    12   15   17
# 1  15    14   11   16
# 2  14    11   19   17
# 3   5     8    6    7

# %% [markdown]
# # Adding Attribute (Columns) name DM

# %%
df3["DM"]=[12,15,16,14]

# %%
df3
# Out:
#    CD  DBMS  CAO  DSS  DM
# 0  10    12   15   17  12
# 1  15    14   11   16  15
# 2  14    11   19   17  16
# 3   5     8    6    7  14

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  CAO  DSS  DM
# 0  10    12   15   17  12
# 2  14    11   19   17  16
# 3   5     8    6    7  14

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    CD  DBMS  CAO  DSS
# 0  10    12   15   17
# 1  15    14   11   16
# 2  14    11   19   17
# 3   5     8    6    7

# %%
#Finding mean of Dss

print("Mean of DSS:", df5["DSS"].mean())
# Out:
# Mean of DSS: 14.25

# %%
#Finding median of Dss

print("Median of DSS:", df5["DSS"].median())
# Out:
# Median of DSS: 16.5

# %%
#Finding mode of Dss

print("Mode of DSS:", df5["DSS"].mode())
# Out:
# Mode of DSS: 0    17
# dtype: int64

# %%
#Finding min of Dss

print("Min of DSS:", df5["DSS"].min())
# Out:
# Min of DSS: 7

# %%
#Finding max of Dss

print("Max of DSS:", df5["DSS"].max())
# Out:
# Max of DSS: 17

# %%
#Creating Student Name List
Name=["harshal","kartik","shrihari","shriram"]
Name
# Out:
# ['harshal', 'kartik', 'shrihari', 'shriram']

# %%
#Creating a Series
Roll_list=pd.Series(Name,index=[1,2,3,4])
print(Roll_list)
# Out:
# 1     harshal
# 2      kartik
# 3    shrihari
# 4     shriram
# dtype: object
